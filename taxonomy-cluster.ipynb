# %% [markdown]
# <a href="https://www.kaggle.com/chasset/happywhale-taxonomy-cluster?scriptVersionId=89578707" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Taxonomy cluster

# %%
import pandas as pd
taxonomy = pd.read_csv("../input/happywhalespeciesclassification/species.csv")
taxonomy.sort_values(by = ['infraorder','family','genus','specy'])
# Out:
#                      specy_id infraorder           family            genus  \
# 12       southern_right_whale    Cetacea       Balaenidae        Eubalaena
# 8                 minke_whale    Cetacea  Balaenopteridae     Balaenoptera
# 14                  sei_whale    Cetacea  Balaenopteridae     Balaenoptera
# 21               brydes_whale    Cetacea  Balaenopteridae     Balaenoptera
# 3                  blue_whale    Cetacea  Balaenopteridae     Balaenoptera
# 10                  fin_whale    Cetacea  Balaenopteridae     Balaenoptera
# 11                 gray_whale    Cetacea  Balaenopteridae     Eschrichtius
# 2              humpback_whale    Cetacea  Balaenopteridae        Megaptera
# 24         commersons_dolphin    Cetacea      Delphinidae  Cephalorhynchus
# 16             common_dolphin    Cetacea      Delphinidae        Delphinus
# 25         pygmy_killer_whale    Cetacea      Delphinidae           Feresa
# ...
